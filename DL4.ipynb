# %% [markdown]
# # Implementation of Backpropagation Algorithm
#
# ## Introduction
#
# Backpropagation is one of the most important algorithms used for training **Artificial Neural Networks (ANNs)**. It is a **supervised learning algorithm** used to minimize the error in a neural network by adjusting the weights and biases.
#
# The algorithm works by **propagating the error backward through the network** and updating the weights using gradient descent.
#
# Backpropagation is commonly used in training **multilayer neural networks**, which makes it a key component of modern **deep learning models**.
#
# ---
#
# ## Neural Network Structure
#
# A typical neural network used in backpropagation consists of three layers:
#
# 1. **Input Layer** – Receives the input data
# 2. **Hidden Layer(s)** – Performs intermediate computations
# 3. **Output Layer** – Produces the final prediction
#
# Each neuron receives inputs, multiplies them by weights, adds a bias, and passes the result through an **activation function**.
#
# ---
#
# ## Forward Propagation
#
# During forward propagation, the input passes through the network layer by layer to produce an output.
#
# The weighted sum of inputs is calculated as:
#
# z = w₁x₁ + w₂x₂ + ... + wₙxₙ + b
#
# This value is passed through an activation function such as **Sigmoid** to produce the output.
#
# Sigmoid activation function:
#
# f(x) = 1 / (1 + e⁻ˣ)
#
# ---
#
# ## Backpropagation Process
#
# Backpropagation works by calculating the **error at the output layer** and propagating it backward to update the weights.
#
# Steps involved:
#
# 1. Perform **forward propagation** to compute the predicted output.
# 2. Calculate the **error** between predicted output and actual output.
# 3. Compute the **gradient of the loss function**.
# 4. Propagate the error backward through the network.
# 5. Update the weights using **gradient descent**.
#
# ---
#
# ## Weight Update Rule
#
# The weights are updated using the following rule:
#
# w(new) = w(old) − η * ∂E/∂w
#
# where:
#
# - **η (eta)** = learning rate
# - **E** = error function
# - **∂E/∂w** = gradient of error with respect to weight
#
# This process is repeated for several iterations until the error is minimized.
#
# ---
#
# ## Advantages of Backpropagation
#
# - Efficient training of multilayer neural networks
# - Automatically adjusts weights
# - Works well for complex nonlinear problems
#
# ---
#
# ## Limitations
#
# - Requires large training datasets
# - Training can be computationally expensive
# - May suffer from **vanishing gradient problem**
#
# ---
#
# ## Conclusion
#
# Backpropagation is a fundamental algorithm used to train neural networks. By iteratively updating weights based on error gradients, it enables neural networks to learn complex patterns and relationships in data, making it essential for modern deep learning applications.

# %%
import numpy as np

# Sigmoid activation function
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# Derivative of sigmoid
def sigmoid_derivative(x):
    return x * (1 - x)

# Input dataset (XOR problem)
X = np.array([[0,0],
              [0,1],
              [1,0],
              [1,1]])

# Output dataset
y = np.array([[0],
              [1],
              [1],
              [0]])

# Seed for reproducibility
np.random.seed(1)

# Initialize weights
input_neurons = 2
hidden_neurons = 2
output_neurons = 1

weights_input_hidden = np.random.uniform(size=(input_neurons, hidden_neurons))
weights_hidden_output = np.random.uniform(size=(hidden_neurons, output_neurons))

bias_hidden = np.random.uniform(size=(1, hidden_neurons))
bias_output = np.random.uniform(size=(1, output_neurons))

learning_rate = 0.5

# Training the network
for epoch in range(10000):

    # Forward propagation
    hidden_layer_input = np.dot(X, weights_input_hidden) + bias_hidden
    hidden_layer_output = sigmoid(hidden_layer_input)

    output_layer_input = np.dot(hidden_layer_output, weights_hidden_output) + bias_output
    predicted_output = sigmoid(output_layer_input)

    # Calculate error
    error = y - predicted_output

    # Backpropagation
    d_predicted_output = error * sigmoid_derivative(predicted_output)

    error_hidden_layer = d_predicted_output.dot(weights_hidden_output.T)
    d_hidden_layer = error_hidden_layer * sigmoid_derivative(hidden_layer_output)

    # Update weights and biases
    weights_hidden_output += hidden_layer_output.T.dot(d_predicted_output) * learning_rate
    weights_input_hidden += X.T.dot(d_hidden_layer) * learning_rate

    bias_output += np.sum(d_predicted_output, axis=0, keepdims=True) * learning_rate
    bias_hidden += np.sum(d_hidden_layer, axis=0, keepdims=True) * learning_rate

print("Predicted Output after training:")
print(predicted_output)
# Out:
# Predicted Output after training:
# [[0.01955901]
#  [0.98309575]
#  [0.98314148]
#  [0.01749147]]
